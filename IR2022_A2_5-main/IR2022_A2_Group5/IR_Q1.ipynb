# %%
## Question 1

# %%
#Part A

# %%
import nltk #this is natural language processing library
nltk.download('stopwords') #we have to download stop words in ordet to remove it.
import re #for regular expressions
import os #for necessary OS functionalities
nltk.download('punkt') #this is for punctuation
import glob 
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer
import numpy as np
from nltk.tokenize import word_tokenize
import operator
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
##Data Preprocessing

# %%
"""DATA PREPROCESSING
"""

def DELSPCCHARS(x):   #upon passing input, this will delete all the special characters.
    #function to delete special characters
    return re.sub(r'[^a-zA-Z0-9\s]','',x)

def FINDINGUniqueWords(w):  #if you will pass list of words, this function will simmply find unique word from that.
    #function to find unique words along with its frequency in the doc

    uw = list(set(w)) #this is the list of unique words which we get through this command
    W = {} #then we have this word frequency dictionary
    for ww in uw: #for evey word in the set of unique words
        W[ww] = w.count(ww) #we are storing the count w.r.t. the word
    return W #and then we are able to generate the word frequency

# 
def process(path):
    #function to find unique words along with its frequency in the doc
    unique_words_dict = {}   #this is the unique words dictionary.
    file_info = {}  #this is the information of the file.
    file_data=[] #this is the data of the file.
    doc_id = 1
    
    for file in glob.glob(path): 
        fpath = file
        # print(file)
        fname = file.split("/")[-1].split(".")[0]       
        if os.path.isdir(file): print(fname)                   
        else: 
            print(doc_id,fname)
            file = open(file,"r",encoding='ISO-8859-1')        
            d = file.read() #reading contents of doc        
            d = DELSPCCHARS(str(d)) #deleting special characters
            d = re.sub(r'\d+','',d) #deleting numbers
            tokens = word_tokenize(d) #extracting tokens
            tltl = [word.lower() for word in tokens] #Removing stopwords                                   
            # tokens_lematized = lematize(tltl)
            tftf = [word for word in tltl if word not in stop_words and len(word) > 1]
            file_info[doc_id] = os.path.basename(fpath)#Storing documents with it's id
            file_data.append(tftf)#storing data of each document in list of list format 
            doc_id += 1
            uq_dict = FINDINGUniqueWords(tftf)
            unique_words_dict.update(uq_dict) #unique words along with number of times it appears in doc
    unique_words = list(set(unique_words_dict)) #list of unique words in all docs combined
    return unique_words_dict,file_info,file_data

path="/content/drive/MyDrive/sem2/Information retreival/HHMF/*"
#preprocessing stories dataset
uwd,FILEINFORMATION,DATAOFTHEFILE=process(path)

#printing file info
print(FILEINFORMATION)

#printing file data
print(DATAOFTHEFILE[1])

#total number of documents
print(len(DATAOFTHEFILE))

#from google.colab import drive
#drive.mount('/content/drive')

def union(query,d):
    #Calculating Union
    result = list(set(query) | set(d))
    return result

def intersection(query,d):
    #Calculating intersection
    result = list(set(query) & set(d))
    return result

def CALC_JACCARD_COEFF(query):
    #Function to Calculate Jaccard Coeffecient
    DOCUMENT_ID=1
    #Dictionary to store jaccard coeff with respective doc-id in key:value format.
    DICTOFJACCARDVALUE={}
    for li in DATAOFTHEFILE:
        # print(val)
        union_result=union(query,li)
        INT_RES=intersection(query,li)
        print(len(union_result))
        print(len(INT_RES))
        #Finding jaccard val for query with each document
        DICTOFJACCARDVALUE[DOCUMENT_ID] = len(INT_RES)/len(union_result)

        DOCUMENT_ID = DOCUMENT_ID + 1
      
    return DICTOFJACCARDVALUE

def CACL_TOP_N(jaccard_list):
    #Function to calculate top 5 documents according to the value of jaccard coeffecient.
    count=0
    jaccard_file=[]

    #Sorting the value of jaccard coeff in decreasing order
    sorted_d = dict( sorted(jaccard_list.items(), key=operator.itemgetter(1),reverse=True))
    print(sorted_d)
    for item in sorted_d.keys():
        #Finding top5 documents

        if (count != 5):
            jaccard_file.append(item)
        else: 
            break
        count=count+1
    
    return jaccard_file

def process_query():
    #Function for Query preprocessing and calculation of jaccard coeff.

    query_input=input("Enter the Input text for Query ")
    query_preprocessed=DELSPCCHARS(query_input)
    tokens = word_tokenize(query_preprocessed )
    Final_Query = [word.lower() for word in tokens if word not in stop_words and len(word) > 1] #Removing stopwords 
    print(Final_Query)
    VAL_JACC=CALC_JACCARD_COEFF(Final_Query)
    print(VAL_JACC)
    top5=CACL_TOP_N(VAL_JACC)
    print(top5)
    return top5

final_result=process_query()

print("top 5 documents are:")
for i in final_result:
    print(FILEINFORMATION[i])
# Out:
# 1 bbq
# 2 grommet
# 3 mothers
# 4 harmful
# 5 mowers
# 6 hell
# 7 herb!
# 8 hate
# 9 icm
# 10 murph
# 11 howlong
# 12 hi
# 13 roach
# 14 conan
# 15 coyote
# 16 imprrisk
# 17 horoscop
# 18 incarhel
# 19 murphy
# 20 bible
# 21 dirtword
# 22 insanity
# 23 impurmat
# 24 interv
# 25 insure
# 26 investi
# 27 cartoon_
# 28 bless
# 29 ivan
# 30 japrap
# 31 terms
# 32 jac&tuu
# 33 test
# 34 dym
# 35 killer
# 36 blooprs1
# 37 testchri
# 38 kid_diet
# 39 lawsuniv
# 40 kilsmur
# 41 test2
# 42 killself
# 43 lbinter
# 44 motrbike
# 45 murphys
# 46 ludeinfo
# 47 legal
# 48 simp
# 49 llong
# 50 office
# 51 lifeinfo
# 52 livnware
# 53 looser
# 54 lll
# 55 lif&love
# 56 lifeimag
# 57 lobquad
# 58 losers84
# 59 losers86
# 60 lozerzon
# 61 catstory
# 62 lozeuser
# 63 phunatdi
# 64 luggage
# 65 ludeinfo
# 66 m0dzmen
# 67 luzerzo2
# 68 manspace
# 69 manilla
# 70 madscrib
# 71 makebeer
# 72 maecenas
# 73 mailfrag
# 74 meinkamp
# 75 mtm
# 76 melodram
# 77 pun
# 78 mash
# 79 marines
# 80 memo
# 81 miranda
# 82 miamadvi
# 83 reasons
# 84 miami
# 85 f_tang
# 86 calvin
# 87 missheav
# 88 mutate
# 89 montpyth
# 90 mydaywss
# 91 misery
# 92 mrscienc
# 93 cars
# 94 news
# 95 myheart
# 96 newmex
# 97 newconst
# 98 naivewiz
# 99 boston
# 100 nysucks
# 101 cartwb
# 102 novel
# 103 nurds
# 104 nuke
# 105 cartoon
# 106 nukeplay
# 107 ohandre
# 108 chunnel
# 109 odearakk
# 110 o-ttalk
# 111 oilgluts
# 112 onetoone
# 113 oldeng
# 114 ozarks
# 115 onetotwo
# 116 p-law
# 117 deep
# 118 ookpik
# 119 opinion
# 120 phony
# 121 pizzawho
# 122 parabl
# 123 phorse
# 124 passage
# 125 peatchp
# 126 planeget
# 127 policpig
# 128 devils
# 129 prayer
# 130 poll2res
# 131 popconc
# 132 prawblim
# 133 dieter
# 134 popmusi
# 135 dead-r
# 136 pro-fact
# 137 psilaine
# 138 quest
# 139 reagan
# 140 radiolaf
# 141 raven
# 142 fuckyou2
# 143 ratings
# 144 donut
# 145 ratspit
# 146 rapmastr
# 147 drinkrul
# 148 research
# 149 docspeak
# 150 repair
# 151 reddye
# 152 rentals
# 153 report
# 154 ripoffpc
# 155 rocking
# 156 rockmus
# 157 dubltalk
# 158 drunk
# 159 t_zone
# 160 insult
# 161 corporat
# 162 cucumber
# 163 takenote
# 164 smackjok
# 165 skippy
# 166 smurfkil
# 167 iqtest
# 168 jokes
# 169 shuttleb
# 170 socecon
# 171 terbear
# 172 teens
# 173 spider
# 174 solviets
# 175 spydust
# 176 soleleer
# 177 social
# 178 stone
# 179 standard
# 180 sungenu
# 181 top10
# 182 termpoem
# 183 t-10
# 184 t-shirt
# 185 talebeat
# 186 texican
# 187 terrmcd'
# 188 languag
# 189 televisi
# 190 taping
# 191 y
# 192 tickmoon
# 193 textgrap
# 194 tfepisod
# 195 test
# 196 terrnieg
# 197 thecube
# 198 timetr
# 199 tfpoems
# 200 koans
# 201 hecomes
# 202 lawyer
# 203 toxcwast
# 204 let
# 205 the_math
# 206 thesis
# 207 voltron
# 208 trekwes
# 209 truths
# 210 cartoon
# 211 truthlsd
# 212 turbo
# 213 tribble
# 214 thermite
# 215 twinkie
# 216 why-me
# 217 wedding
# 218 wagon
# 219 whoon1st
# 220 wetdream
# 221 whoops
# 222 word
# 223 xtermin8
# 224 yjohncse
# 225 worldend
# 226 yuppies
# 227 who
# 228 billcat
# 229 zodiac
# 230 trukdeth
# 231 liceprof
# 232 limerick
# 233 jeffie
# 234 hotnnot
# 235 urban
# 236 tshirts
# 237 lines
# 238 units
# 239 vaguemag
# 240 st_silic
# 241 waitress
# 242 wagit
# 243 washroom
# 244 univ
# 245 strine
# 246 marriage
# 247 weight
# 248 welfare
# 249 lotsa
# 250 lion
# 251 math
# 252 math
# 253 yogisays
# 254 misc
# 255 wimptest
# 256 math
# 257 woodbugs
# 258 lozers
# 259 zgtoilet
# 260 xibovac
# 261 woolly_m
# 262 chainltr
# 263 climbing
# 264 church
# 265 commutin
# 266 co-car
# 267 netnews
# 268 childhoo
# 269 nigel
# 270 nigel
# 271 electric
# 272 eandb
# 273 court
# 274 elephant
# 275 nigel
# 276 hack
# 277 element
# 278 fartting
# 279 fascist
# 280 drinker
# 281 exam
# 282 excuses
# 283 fartinfo
# 284 idr2
# 285 nigel
# 286 nigel
# 287 final-ex
# 288 jokes
# 289 ourfathr
# 290 nigel
# 291 lawhunt
# 292 fuck!
# 293 fusion
# 294 nigel
# 295 lawskool
# 296 gas
# 297 rec
# 298 gd_guide
# 299 grammar
# 300 good
# 301 grospoem
# 302 passenge
# 303 german
# 304 nintendo
# 305 poli_t
# 306 polemom
# 307 potty
# 308 pepsideg
# 309 polly
# 310 pickup
# 311 polly_
# 312 moonshin
# 313 pournell
# 314 dover
# 315 proof
# 316 problem
# 317 psalm_re
# 318 proposal
# 319 pure
# 320 psalm23
# 321 pukeprom
# 322 psych_pr
# 323 prover_w
# 324 prooftec
# 325 college
# 326 leech
# 327 puzzles
# 328 curse
# 329 peanuts
# 330 python_s
# 331 quux_p
# 332 tuflife
# 333 flowchrt
# 334 pickup
# 335 pecker
# 336 smartass
# 337 height
# 338 eskimo
# 339 prac1
# 340 pipespec
# 341 hitlerap
# 342 hitler
# 343 hilbilly
# 344 how_to_i
# 345 steroid
# 346 hoosier
# 347 horoscop
# 348 htswfren
# 349 snipe
# 350 smokers
# 351 prac3
# 352 stereo
# 353 insuranc
# 354 idaho
# 355 televisi
# 356 inlaws1
# 357 humatran
# 358 sysadmin
# 359 law
# 360 humatra
# 361 realest
# 362 jargon
# 363 woodbine
# 364 kloo
# 365 italoink
# 366 jokeju07
# 367 jc-elvis
# 368 psycho
# 369 letter
# 370 rednecks
# 371 lampoon
# 372 sysman
# 373 letter_f
# 374 laws
# 375 letgosh
# 376 odd_to
# 377 lions
# 378 luvstory
# 379 prac4
# 380 farsi
# 381 nukwaste
# 382 lucky
# 383 one
# 384 socks
# 385 signatur
# 386 smurfs
# 387 smiley
# 388 primes
# 389 oracle
# 390 oxymoron
# 391 some_hu
# 392 spelin_r
# 393 studentb
# 394 strsdiet
# 395 princess
# 396 startrek
# 397 puzzle
# 398 mr
# 399 jrrt
# 400 telecom
# 401 humpty
# 402 shrink
# 403 prover
# 404 number
# 405 un
# 406 psalm
# 407 poli
# 408 quick
# 409 quantum
# 410 nosuch_nasfic
# 411 rent-a_cat
# 412 psalm_nixon
# 413 popmach
# 414 resrch_phrase
# 415 rinaldos
# 416 progrs
# 417 quotes
# 418 quotes
# 419 racist
# 420 shorties
# 421 texican
# 422 welfare
# 423 temphell
# 424 tnd
# 425 quotes
# 426 top10
# 427 squids
# 428 wisdom
# 429 bw-summe
# 430 aussie
# 431 bw-phwan
# 432 justify
# 433 outawork
# 434 speling
# 435 firstaid
# 436 la_times
# 437 supermar
# 438 oasis
# 439 oldtime
# 440 ambrose
# 441 oxymoron
# 442 gaiahuma
# 443 kid2
# 444 anim_lif
# 445 bad
# 446 wood
# 447 talkbizr
# 448 woodsmok
# 449 bagelope
# 450 variety1
# 451 variety3
# 452 empeval
# 453 variety2
# 454 epitaph
# 455 engrhyme
# 456 various
# 457 english
# 458 excuse30
# 459 excuse
# 460 vegkill
# 461 quack26
# 462 vonthomp
# 463 q
# 464 godmonth
# 465 gown
# 466 growth
# 467 cogdis
# 468 b12
# 469 mrsfield
# 470 hamburge
# 471 tuna
# 472 brewing
# 473 beginn
# 474 chili
# 475 mead
# 476 newcoke
# 477 cooking
# 478 candybar
# 479 coke1
# 480 coladrik
# 481 coke
# 482 vegan
# 483 jerky
# 484 snapple
# 485 meat2
# 486 coladrik
# 487 bakebred
# 488 oculis
# 489 drinks
# 490 pepper
# 491 fiber
# 492 x-drinks
# 493 turkey
# 494 fajitas
# 495 choco-ch
# 496 oatbran
# 497 recepies
# 498 kashrut
# 499 bread
# 500 coke_fan
# 501 candy
# 502 curry
# 503 appetiz
# 504 coke
# 505 fudge
# 506 aclamt
# 507 hotel
# 508 boneles2
# 509 dthought
# 510 tpquote2
# 511 tpquotes
# 512 gingbeer
# 513 gameshow
# 514 cooking
# 515 rinaldo
# 516 women
# 517 wrdnws1
# 518 wrdnws2
# 519 wrdnws3
# 520 wrdnws4
# 521 wrdnws5
# 522 wrdnws6
# 523 wrdnws7
# 524 wrdnws8
# 525 wrdnws9
# 526 letterbx
# 527 hierarch
# 528 ads
# 529 adt_miam
# 530 epikarat
# 531 earp
# 532 namm
# 533 kanalx
# 534 gd_flybd
# 535 widows
# 536 twinpeak
# 537 lazarus
# 538 hoonsrc
# 539 barney
# 540 barney
# 541 bb
# 542 bimg
# 543 bmdn01
# 544 libraway
# 545 wisconsi
# 546 twinkies
# 547 sanshop
# 548 scam
# 549 seeds42
# 550 top10st1
# 551 top10st2
# 552 transp
# 553 mundane
# 554 japantv
# 555 johann
# 556 just2
# 557 bnb_quot
# 558 bored
# 559 sw_err
# 560 skippy
# 561 recip1
# 562 shooters
# 563 slogans
# 564 smurf-03
# 565 smurf_co
# 566 soccer
# 567 beerjesus
# 568 bozo_tv
# 569 coffee
# 570 diet
# 571 jason
# 572 econridl
# 573 oliver
# 574 oliver02
# 575 sf-zine
# 576 subrdead
# 577 topten
# 578 how2bgod
# 579 hangover
# 580 netmask
# 581 chickens
# 582 classicm
# 583 cmu
# 584 commword
# 585 cookbkly
# 586 fearcola
# 587 hedgehog
# 588 horflick
# 589 alcohol
# 590 bbh_intv
# 591 beer-g
# 592 beergame
# 593 dining
# 594 iced
# 595 thievco
# 596 aeonint
# 597 mindvox
# 598 deathhem
# 599 bread
# 600 brownie
# 601 lion
# 602 lp-assoc
# 603 desk
# 604 disclym
# 605 flowchrt
# 606 flux_fix
# 607 packard
# 608 parsnip
# 609 penisprt
# 610 msfields
# 611 mtv
# 612 modstup
# 613 moslem
# 614 mov_rail
# 615 miamimth
# 616 missdish
# 617 consp
# 618 food
# 619 foodtips
# 620 cake
# 621 docdict
# 622 drinks
# 623 drive
# 624 bhang
# 625 booze1
# 626 booze2
# 627 cgs_lst
# 628 golnar
# 629 red-neck
# 630 reddwarf
# 631 renorthr
# 632 rns_bcl
# 633 rns_bwl
# 634 rns_ency
# 635 robot
# 636 subb_lis
# 637 staff
# 638 stuf10
# 639 stuf11
# 640 fusion
# 641 sfmovie
# 642 the_ant
# 643 mog-history
# 644 dalive
# 645 iremember
# 646 kilroy
# 647 cform2
# 648 msorrow
# 649 nameisreo
# 650 inquirer
# 651 ins1
# 652 buldrwho
# 653 bnbguide
# 654 epi_rns
# 655 epi_
# 656 epi_tton
# 657 gd_alf
# 658 epi_merm
# 659 epi_bnb
# 660 episimp2
# 661 gd_drwho
# 662 outlimit
# 663 lost
# 664 twilight
# 665 gd_gal
# 666 scratchy
# 667 gd_liqtv
# 668 gd_frasr
# 669 gd_maxhd
# 670 gd_ol
# 671 gd_hhead
# 672 epiquest
# 673 gd_sgrnd
# 674 gd_ql
# 675 ghostsch
# 676 gd_tznew
# 677 a-team
# 678 a_fish_c
# 679 a_tv_t-p
# 680 aboutada
# 681 adrian_e
# 682 allfam
# 683 allusion
# 684 amazing
# 685 anime
# 686 anime
# 687 hbo_spec
# 688 highland
# 689 hitchcok
# 690 wacky
# 691 wkrp
# 692 cast
# 693 christop
# 694 chung
# 695 clancy
# 696 comic_st
# 697 cultmov
# 698 maxheadr
# 699 facedeth
# 700 farsi
# 701 nukewar
# 702 number
# 703 spoonlis
# 704 sinksub
# 705 sorority
# 706 petshop
# 707 prac2
# 708 pracjoke
# 709 fed
# 710 cybrtrsh
# 711 hstlrtxt
# 712 homermmm
# 713 how2dotv
# 714 filmgoof
# 715 films_gl
# 716 fish
# 717 hitchcoc
# 718 is_story
# 719 fegg!int
# 720 feggaqui
# 721 feggmagi
# 722 normquot
# 723 history2
# 724 pol-corr
# 725 poopie
# 726 ppbeer
# 727 pot
# 728 headlnrs
# 729 hell
# 730 hum2
# 731 humor9
# 732 cokeform
# 733 contract
# 734 cookberk
# 735 cookie
# 736 cooplaws
# 737 cuisine
# 738 coffee
# 739 modemwld
# 740 minn
# 741 oam-001
# 742 oam
# 743 acronym
# 744 college
# 745 english
# 746 figure_1
# 747 crzycred
# 748 arnold
# 749 ateam
# 750 avengers
# 751 bbc_vide
# 752 beauty
# 753 blackadd
# 754 blake7
# 755 doc-says
# 756 dromes
# 757 eatme
# 758 free-cof
# 759 initials
# 760 old
# 761 post
# 762 quantum
# 763 resolutn
# 764 soporifi
# 765 swearfrn
# 766 tarot
# 767 c0dez
# 768 beer
# 769 butcher
# 770 curiousgeorgie
# 771 freudonseuss
# 772 normalboy
# 773 annoy
# 774 booze
# 775 diesmurf
# 776 elevator
# 777 get
# 778 how
# 779 normal
# 780 practica
# 781 dead2
# 782 dead3
# 783 dead4
# 784 dead5
# 785 radexposed
# 786 carowner
# 787 pat
# 788 bugs
# 789 hack7
# 790 happyhack
# 791 airlines
# 792 skincat
# 793 venganza
# 794 venison
# 795 homebrew
# 796 hop
# 797 hotpeper
# 798 necropls
# 799 three
# 800 dandwine
# 801 egglentl
# 802 eggroll1
# 803 egg-bred
# 804 engmuffn
# 805 focaccia
# 806 frogeye1
# 807 feista01
# 808 firecamp
# 809 garlpast
# 810 goldwatr
# 811 texbeef
# 812 greenchi
# 813 woods
# 814 wonton
# 815 gack!
# 816 unochili
# 817 whitbred
# 818 yogurt
# 819 insult
# 820 insults1
# 821 calamus
# 822 damiana
# 823 imbecile
# 824 oranchic
# 825 pbcookie
# 826 orgfrost
# 827 pasta001
# 828 penndtch
# 829 jon
# 830 hackmorality
# 831 whatbbs
# 832 hermsys
# 833 arcadian
# 834 appbred
# 835 antimead
# 836 apsaucke
# 837 awespinh
# 838 applepie
# 839 banana02
# 840 banana05
# 841 beershrm
# 842 batrbred
# 843 banana04
# 844 beershrp
# 845 banana03
# 846 baklava
# 847 banana01
# 848 berryeto
# 849 jawsalad
# 850 jambalay
# 851 jalapast
# 852 japice
# 853 jawgumbo
# 854 jungjuic
# 855 zuccmush
# 856 stagline
# 857 seafood
# 858 strattma
# 859 montoys
# 860 margos
# 861 mitch
# 862 zucantom
# 863 shuimai
# 864 blkbean
# 865 boarchil
# 866 blkbnsrc
# 867 btscke01
# 868 btscke03
# 869 bredcake
# 870 breadpud
# 871 bread
# 872 btscke02
# 873 brdpudd
# 874 burrito
# 875 buffwing
# 876 caesardr
# 877 btscke05
# 878 bunacald
# 879 butstcod
# 880 btscke04
# 881 capital
# 882 caramels
# 883 advrtize
# 884 bitnet
# 885 nzdrinks
# 886 recipe
# 887 recipe
# 888 recipe
# 889 recipe
# 890 recipe
# 891 recipe
# 892 recipe
# 893 richbred
# 894 recipe
# 895 recipe
# 896 recipe
# 897 oldtime
# 898 oakwood
# 899 recipe
# 900 recipe
# 901 renored
# 902 all_grai
# 903 amchap2
# 904 beer
# 905 beergame
# 906 beer-gui
# 907 gotukola
# 908 hitler
# 909 coollngo2
# 910 jimhood
# 911 acne1
# 912 aphrodis
# 913 bw
# 914 back1
# 915 blood
# 916 booknuti
# 917 acetab1
# 918 anorexia
# 919 atherosc
# 920 beesherb
# 921 1st_aid
# 922 cereal
# 923 chinese
# 924 arthriti
# 925 aniherb
# 926 curry
# 927 ayurved
# 928 brush1
# 929 critic
# 930 antibiot
# 931 proudlyserve
# 932 jayjay
# 933 bnbeg2
# 934 att
# 935 calculus
# 936 gumbo
# 937 btaco
# 938 beerwarn
# 939 byfb
# 940 qttofu
# 941 paddingurpapers
# 942 cartoon_laws
# 943 coffeebeerwomen
# 944 collected_quotes
# 945 childrenbooks
# 946 aggie
# 947 llamas
# 948 trekfume
# 949 confucius_say
# 950 enlightenment
# 951 labels
# 952 horoscope
# 953 fireplacein
# 954 ganamembers
# 955 girlspeak
# 956 religion
# 957 turing
# 958 valujet
# 959 computer
# 960 jokes1
# 961 lawyers
# 962 cops
# 963 fbipizza
# 964 mcd
# 965 nasaglenn
# 966 bhb
# 967 bond-2
# 968 indgrdn
# 969 insect1
# 970 quantity
# 971 sawyer
# 972 exidy
# 973 deadlysins
# 974 yuban
# 975 planetzero
# 976 aids
# 977 reeves
# 978 moore
# 979 chickenheadbbs
# 980 phxbbs-m
# 981 ukunderg
# 982 silverclaws
# 983 namaste
# 984 crazy
# 985 lifeonledge
# 986 lipkovits
# 987 basehead
# 988 draxamus
# 989 stressman
# 990 exylic
# 991 apsnet
# 992 lansing
# 993 heroic
# 994 onan
# 995 teevee
# 996 grail
# 997 mel
# 998 disclmr
# 999 hacktest
# 1000 hackingcracking
# 1001 analogy
# 1002 charity
# 1003 adameve
# 1004 bingbong
# 1005 ghostfun
# 1006 cheapfar
# 1007 modest
# 1008 mlverb
# 1009 poets
# 1010 saveface
# 1011 reconcil
# 1012 parades
# 1013 drugshum
# 1014 solders
# 1015 weights
# 1016 brainect
# 1017 throwawa
# 1018 shameonu
# 1019 symbol
# 1020 watchlip
# 1021 whatthe
# 1022 spacever
# 1023 kaboom
# 1024 hammock
# 1025 memory
# 1026 sigs
# 1027 zen
# 1028 adcopy
# 1029 nigel
# 1030 b-2
# 1031 manager
# 1032 abbott
# 1033 admin
# 1034 suicide2
# 1035 alcatax
# 1036 acronym
# 1037 alflog
# 1038 nigel10
# 1039 atombomb
# 1040 cancer
# 1041 answers
# 1042 badday
# 1043 bank
# 1044 boatmemo
# 1045 alabama
# 1046 beer
# 1047 catin
# 1048 beave
# 1049 beapimp
# 1050 bitchcar
# 1051 blackapp
# 1052 argotdic
# 1053 bigpic1
# 1054 blackhol
# 1055 cold
# 1056 cheapin
# 1057 blaster
# 1058 boe
# 1059 browneco
# 1060 btcisfre
# 1061 buzzword
# 1062 bugbreak
# 1063 cabbage
# 1064 butwrong
# 1065 chickens
# 1066 merry
# 1067 calif
# 1068 cockney
# 1069 nihgel_8
# 1070 catballs
# 1071 catranch
# 1072 macsfarm
# 1073 chinesec
# 1074 cbmatic
# 1075 change
# 1076 college
# 1077 making_y
# 1078 madhattr
# 1079 nukewar
# 1080 coldfake
# 1081 malechem
# 1082 number_k
# 1083 arab
# 1084 cucumber
# 1085 manners
# 1086 comrevi1
# 1087 anthropo
# 1088 addrmeri
# 1089 readme
# 1090 cowexplo
# 1091 rabbit
# 1092 dark
# 1093 d-ned
# 1094 failure
# 1095 cuchy
# 1096 art-fart
# 1097 dingding
# 1098 druggame
# 1099 deterior
# 1100 defectiv
# 1101 disaster
# 1102 roadpizz
# 1103 acronyms
# 1104 bad-d
# 1105 engineer
# 1106 doggun
# 1107 age
# 1108 murphy_l
# 1109 enquire
# 1110 beerdiag
# 1111 bad
# 1112 firstaid
# 1113 drinking
# 1114 record_
# 1115 middle
# 1116 flattax
# 1117 finalexm
# 1118 relative
# 1119 footfun
# 1120 moose
# 1121 forsooth
# 1122 revolt
# 1123 residncy
# 1124 from
# 1125 resrch_p
# 1126 freshman
# 1127 men&wome
# 1128 fwksfun
# 1129 mensroom
# 1130 goforth
# 1131 female
# 1132 gohome
# 1133 rinaldos
# {1: 'bbq.txt', 2: 'grommet.hum', 3: 'mothers.txt', 4: 'harmful.hum', 5: 'mowers.txt', 6: 'hell.jok', 7: 'herb!.hum', 8: 'hate.hum', 9: 'icm.hum', 10: 'murph.jok', 11: 'howlong.hum', 12: 'hi.tec', 13: 'roach.asc', 14: 'conan.txt', 15: 'coyote.txt', 16: 'imprrisk.hum', 17: 'horoscop.jok', 18: 'incarhel.hum', 19: 'murphy.txt', 20: 'bible.txt', 21: 'dirtword.txt', 22: 'insanity.hum', 23: 'impurmat.hum', 24: 'interv.hum', 25: 'insure.hum', 26: 'investi.hum', 27: 'cartoon_.txt', 28: 'bless.bc', 29: 'ivan.hum', 30: 'japrap.hum', 31: 'terms.hum', 32: 'jac&tuu.hum', 33: 'test.jok', 34: 'dym', 35: 'killer.hum', 36: 'blooprs1.asc', 37: 'testchri.txt', 38: 'kid_diet.txt', 39: 'lawsuniv.hum', 40: 'kilsmur.hum', 41: 'test2.jok', 42: 'killself.hum', 43: 'lbinter.hum', 44: 'motrbike.jok', 45: 'murphys.txt', 46: 'ludeinfo.txt', 47: 'legal.hum', 48: 'simp.txt', 49: 'llong.hum', 50: 'office.txt', 51: 'lifeinfo.hum', 52: 'livnware.hum', 53: 'looser.hum', 54: 'lll.hum', 55: 'lif&love.hum', 56: 'lifeimag.hum', 57: 'lobquad.hum', 58: 'losers84.hum', 59: 'losers86.hum', 60: 'lozerzon.hum', 61: 'catstory.txt', 62: 'lozeuser.hum', 63: 'phunatdi.ana', 64: 'luggage.hum', 65: 'ludeinfo.hum', 66: 'm0dzmen.hum', 67: 'luzerzo2.hum', 68: 'manspace.hum', 69: 'manilla.hum', 70: 'madscrib.hum', 71: 'makebeer.hum', 72: 'maecenas.hum', 73: 'mailfrag.hum', 74: 'meinkamp.hum', 75: 'mtm.hum', 76: 'melodram.hum', 77: 'pun.txt', 78: 'mash.hum', 79: 'marines.hum', 80: 'memo.hum', 81: 'miranda.hum', 82: 'miamadvi.hum', 83: 'reasons.txt', 84: 'miami.hum', 85: 'f_tang.txt', 86: 'calvin.txt', 87: 'missheav.hum', 88: 'mutate.hum', 89: 'montpyth.hum', 90: 'mydaywss.hum', 91: 'misery.hum', 92: 'mrscienc.hum', 93: 'cars.txt', 94: 'news.hum', 95: 'myheart.hum', 96: 'newmex.hum', 97: 'newconst.hum', 98: 'naivewiz.hum', 99: 'boston.geog', 100: 'nysucks.hum', 101: 'cartwb.son', 102: 'novel.hum', 103: 'nurds.hum', 104: 'nuke.hum', 105: 'cartoon.law', 106: 'nukeplay.hum', 107: 'ohandre.hum', 108: 'chunnel.txt', 109: 'odearakk.hum', 110: 'o-ttalk.hum', 111: 'oilgluts.hum', 112: 'onetoone.hum', 113: 'oldeng.hum', 114: 'ozarks.hum', 115: 'onetotwo.hum', 116: 'p-law.hum', 117: 'deep.txt', 118: 'ookpik.hum', 119: 'opinion.hum', 120: 'phony.hum', 121: 'pizzawho.hum', 122: 'parabl.hum', 123: 'phorse.hum', 124: 'passage.hum', 125: 'peatchp.hum', 126: 'planeget.hum', 127: 'policpig.hum', 128: 'devils.jok', 129: 'prayer.hum', 130: 'poll2res.hum', 131: 'popconc.hum', 132: 'prawblim.hum', 133: 'dieter.txt', 134: 'popmusi.hum', 135: 'dead-r', 136: 'pro-fact.hum', 137: 'psilaine.hum', 138: 'quest.hum', 139: 'reagan.hum', 140: 'radiolaf.hum', 141: 'raven.hum', 142: 'fuckyou2.txt', 143: 'ratings.hum', 144: 'donut.txt', 145: 'ratspit.hum', 146: 'rapmastr.hum', 147: 'drinkrul.jok', 148: 'research.hum', 149: 'docspeak.txt', 150: 'repair.hum', 151: 'reddye.hum', 152: 'rentals.hum', 153: 'report.hum', 154: 'ripoffpc.hum', 155: 'rocking.hum', 156: 'rockm
 'send', 'bike', 'back', 'manufacturer', 'repairs', 'due', 'botching', 'job', 'writes', 'funny', 'piece', 'order', 'recoup', 'freight', 'expenses', 'way', 'isnt', 'one', 'articles', 'gas', 'grill', 'works', 'fine', 'episode', 'bring', 'mind', 'couple', 'pet', 'theories', 'kitmaking', 'first', 'socalled', 'ease', 'assembly', 'american', 'manufacturers', 'think', 'group', 'employees', 'write', 'instruction', 'manual', 'product', 'effort', 'translated', 'japanese', 'spanish', 'depending', 'kit', 'packed', 'either', 'japanese', 'mexican', 'retranslates', 'manual', 'english', 'prints', 'stuffs', 'parts', 'thats', 'explanation', 'ponderous', 'yes', 'tortuous', 'nature', 'instruction', 'manuals', 'second', 'theory', 'cant', 'fault', 'quality', 'workmanship', 'youre', 'one', 'drive', 'chain', 'kitassembled', 'ten', 'speed', 'bike', 'falls', 'gas', 'grill', 'blows', 'face', 'madeatnightathome', 'color', 'tv', 'set', 'works', 'channel', 'blame', 'sure', 'cant', 'blame', 'wife', 'kids', 'cat', 'even', 'never', 'let', 'forget', 'ten', 'speed', 'color', 'gas', 'grill', 'sitting', 'useless', 'back', 'porch']
# 1133
# Enter the Input text for Query lion stood thoughtfully for a moment
# ['lion', 'stood', 'thoughtfully', 'moment']
# 151
# 0
# 224
# 0
# 184
# 0
# 273
# 0
# 191
# 0
# 230
# 0
# 282
# 0
# 277
# 0
# 114
# 0
# 460
# 0
# 393
# 0
# 500
# 0
# 75
# 0
# 859
# 1
# 712
# 1
# 504
# 0
# 235
# 0
# 158
# 1
# 302
# 0
# 47
# 0
# 380
# 0
# 439
# 0
# 292
# 0
# 294
# 0
# 176
# 0
# 322
# 0
# 274
# 0
# 134
# 0
# 364
# 1
# 175
# 0
# 496
# 0
# 604
# 0
# 496
# 0
# 1022
# 0
# 99
# 0
# 748
# 0
# 257
# 0
# 285
# 0
# 221
# 0
# 173
# 0
# 296
# 0
# 488
# 0
# 1071
# 1
# 147
# 0
# 991
# 2
# 487
# 0
# 398
# 0
# 174
# 0
# 1396
# 1
# 125
# 0
# 303
# 0
# 170
# 0
# 726
# 0
# 392
# 0
# 414
# 1
# 622
# 2
# 73
# 0
# 888
# 0
# 479
# 0
# 666
# 1
# 152
# 0
# 1665
# 0
# 356
# 0
# 329
# 1
# 436
# 0
# 757
# 1
# 560
# 0
# 583
# 0
# 153
# 0
# 822
# 0
# 268
# 0
# 672
# 2
# 257
# 1
# 491
# 1
# 461
# 0
# 772
# 0
# 522
# 0
# 1362
# 1
# 113
# 0
# 82
# 0
# 229
# 0
# 232
# 0
# 175
# 1
# 526
# 0
# 230
# 0
# 387
# 0
# 219
# 0
# 211
# 0
# 1616
# 2
# 654
# 0
# 173
# 0
# 483
# 0
# 278
# 0
# 256
# 1
# 703
# 0
# 195
# 0
# 220
# 0
# 141
# 0
# 18
# 0
# 192
# 0
# 258
# 0
# 859
# 0
# 192
# 0
# 1257
# 0
# 278
# 0
# 264
# 0
# 128
# 0
# 189
# 0
# 75
# 0
# 312
# 0
570824524312897, 968: 0.001053740779768177, 269: 0.0010482180293501049, 533: 0.001040582726326743, 559: 0.001040582726326743, 339: 0.0009596928982725527, 981: 0.000949667616334283, 752: 0.0009478672985781991, 351: 0.000946073793755913, 489: 0.000942507068803016, 634: 0.0009345794392523365, 43: 0.0009337068160597573, 649: 0.0009025270758122744, 944: 0.0008956560680698612, 540: 0.0008900756564307966, 444: 0.000881057268722467, 686: 0.000881057268722467, 202: 0.0008445945945945946, 884: 0.0008340283569641367, 136: 0.0008203445447087777, 254: 0.0008183306055646482, 260 ...
# [462, 327, 1014, 1105, 217]
# top 5 documents are:
# vonthomp
# puzzles.jok
# solders.hum
# engineer.hum
# wedding.hum

# %%
#Part B
import nltk
nltk.download('stopwords')
import nltk
nltk.download('punkt')
import glob
import numpy as np
import re
import nltk
import os
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import operator
stop_words = set(stopwords.words('english')) 
#extracting stop words from nltk repo

def DELSPCCHARS(input): 
    #function to delete special characters
    regex = r'[^a-zA-Z0-9\s]'
    output = re.sub(regex,'',input)
    return output

def FINDINGUniqueWords(words): 
    #function to find unique words along with its frequency in the doc

    unique_words = list(set(words))
    word_freq = {}
    for word in unique_words:
        word_freq[word] = words.count(word)
    return word_freq

def process(path):
    #function to find unique words along with its frequency in the doc
    unique_words_dict = {}   
    file_info = {} 
    file_data=[]
    doc_id = 1
    
    for file in glob.glob(path): 
        fpath = file
        # print(file)
        fname = file.split("/")[-1].split(".")[0]                                      
        if os.path.isdir(file):     
            print(fname)                   
            
        else:
            print(doc_id,fname)
            file = open(file,"r",encoding='ISO-8859-1')        
            d = file.read() #reading contents of doc        
            d = DELSPCCHARS(str(d)) #deleting special characters
            d = re.sub(r'\d+','',d) #deleting numbers
            tokens = word_tokenize(d) #extracting tokens
            tltl = [word.lower() for word in tokens] #Removing stopwords                                   
            # tokens_lematized = lematize(tltl)
            tftf = [word for word in tltl if word not in stop_words and len(word) > 1]
            file_info[doc_id] = os.path.basename(fpath)#Storing documents with it's id
            file_data.append(tftf)#storing data of each document in list of list format 
            doc_id += 1
            uq_dict = FINDINGUniqueWords(tftf)
            unique_words_dict.update(uq_dict) #unique words along with number of times it appears in doc
    unique_words = list(set(unique_words_dict)) #list of unique words in all docs combined
    return unique_words_dict,file_info,file_data

    # return file_info,file_data
    
    
path="/content/drive/MyDrive/sem2/Information retreival/HHMF/*"
#preprocessing stories dataset
unique_words_dict,file_info,file_data=process(path)

#printing file info
print(file_info)

#printing file data
print(file_data[1])

#total number of documents
print(len(file_data))

#TF-IDF CALCULATION"

def idf():
    #Function to find inverse document frequency
   
    #Firstly finding Document Frequency: Number of Documents that contain term t.

    #doc_freq : Dictionary which contain count of number of document for each term in key value format.
    doc_freq = {}

    for item in file_data:
        #traversing through file_data to get count of document for each term.   

        terms  =  list(set(item))#finding all unique ters.
      
        for word in terms:
            #storing count of each term in doc_freq dicitonary.
            if doc_freq.get(word) is not None:
                doc_freq[word] =doc_freq.get(word)+1
            else:
                doc_freq[word] = 1

    #Secondly Finding inverse document frequency: IDF(word)=log(total no. of documents/document frequency(word)+1)

    #Finding total number of documents 
    total_docs=len(file_data)

    #inverse_doc_freq: dictionary to store IDF value.
    inverse_doc_freq = {}

    for word in doc_freq.keys():
        #Calculating IDF value for each term using given formula.
        
        inverse_val=np.log((total_docs)/doc_freq[word]+1)
        inverse_doc_freq[word] = inverse_val

    return doc_freq,inverse_doc_freq

#Calculating inverse document frequency
doc_freq,inverse_doc_freq=idf()

print(doc_freq)

print(inverse_doc_freq)

def term_frequency():
    #Function to Caclulate Term Frequency: Number of particular term t in Document d.

    #list of list to store term frequency where sub list is created for each document.
    final_tf=[]

    for li in file_data:
        #Traversing through file data to get each document.

        #tf: dictionary which contain key value pair in the form of -> "term": count 
        tf={}
        for term in li:  
            #Traversing through each document to get count of terms in that document.
            if tf.get(term) is not None:
                tf[term] =tf.get(term)+1
            else:
                tf[term] = 1

        final_tf.append(tf)
    return final_tf

#Calculating term frequency
term_freq=term_frequency()
print(term_freq[1])

def tf_idf(freq_val):
    #Function to Calculate TF-IDF VALUE= tf*idf

    #list to store calculated tf*idf value for each term in each document.
    final_tf_idf=[]
    
    for term in freq_val:
        #Traversing through each term to calculate it's tf-idf value.
        tf_idf={}
        for word in term.keys():
            tf_idf[word]=term[word]*inverse_doc_freq[word]
        final_tf_idf.append(tf_idf)

    return final_tf_idf

#Binary Term Frequency

#Binary term Frequency

#always be 1 for all values because no word with 0 freq is added in the list,words with list freq 1 are added in the list.
def binary_term_freq(term_freq):
     #Function to Caclulate Binary Term Frequency

     #list of list to store binary term frequency where sub list is created for each document. 
    binary_tf= []

    for term in term_freq:
         #Traversing through term_freq 
        tf = {}
    
        for word in term.keys():
            #Fingng binary term frequency.
            if term.get(word) < 0:
                tf[word] = 0
            else:
                tf[word] = 1
            
        binary_tf.append(tf)
    return binary_tf

#Calculating binary tf
binary_tf=binary_term_freq(term_freq)
print(binary_tf[1])

print("\n")

#calculating tfidf value for binary weighting scheme
binary_tfidf=tf_idf(binary_tf)
print(binary_tfidf[1])



#Raw count term frequency
def raw_count_tf(term_freq):
    #Function to calculate raw count term frequency.

    raw_count_tf= term_freq
    return raw_count_tf

#Calculating raw count tf
raw_count_tf=raw_count_tf(term_freq)
print(raw_count_tf[1])

print("\n")

#calculating tfidf value for RAW COUNT weighting scheme
raw_count_tfidf=tf_idf(raw_count_tf)
print(raw_count_tfidf[1])



#Term Frequency

def term_Freq(term_freq):
     #Function to calculate Term Frequency.

     #list of list to store binary Term Frequency where sub list is created for each document. 
    Term_Frequency = []

    
    for term in term_freq:
        #Traversing through term_freq
        tf = {}
        values = term.values() #Return values of a dictionary.
        total = sum(values) #Compute sum of the values.
        # print(total)

        for word in term.keys():
            #Calculating Term Frequency for each word.
 
            tf[word]=term.get(word)/total

        Term_Frequency.append(tf)
    return Term_Frequency

#Calculating term frequency
Term_Frequency=term_Freq(term_freq)
print(Term_Frequency[1])

print("\n")
Term_Frequency_tfidf=tf_idf(Term_Frequency)
print(Term_Frequency_tfidf[1])



#Log term frequency
def Log_term_freq(term_freq):
     #Function to calculate log normalized Term Frequency.

    #list of list to store log normalized Term Frequency where sub list is created for each document. 
    log_tf = []

    for term in term_freq:
        tf = {}

        for word in term.keys():
            #Calculating log tf value for each term

            tf[word]=np.log(1+term.get(word))

        log_tf.append(tf)
    return log_tf

#Calculating log tf
log_tf=Log_term_freq(term_freq)

print(log_tf[1])
print("\n")
log_tfidf=tf_idf(log_tf)

print(log_tfidf[1])


#Double Log Normalization

def double_Log_term_freq(term_freq):
     #Function to calculate double log normalized Term Frequency.

    #list of list to store double log normalized Term Frequency where sub list is created for each document. 
    double_log_tf = []

    for term in term_freq:
        tf = {}
        max_tf=max(term.values())
        for word in term.keys():

            tf[word]=0.5 + 0.5*(term.get(word)/max_tf)

        double_log_tf.append(tf)
    return double_log_tf

#Calculating double log normalized term frequency
double_log_tf=double_Log_term_freq(term_freq)

print(double_log_tf[1])
print("\n")

double_log_tfidf=tf_idf(double_log_tf)
print(double_log_tfidf[1])

#Creating list of all available term in document.
total_terms=list(doc_freq.keys())
print(total_terms)
len(total_terms)


def calculate_top(tfidf_val,query):


    dict_tfidf_val={}

    for i in range(len(file_data)+1):
        dict_tfidf_val[i] = 0.0

    for word in query:
        #Traversing through query 
        doc_id=0
        for val in tfidf_val:
            #Traversing through each document to check if query term is present in that document, if present then storing tfidf val with document id.
            doc_id=doc_id+1
            if word in val:
                
                dict_tfidf_val[doc_id]=dict_tfidf_val[doc_id]+val[word]

    sorted_d=dict(sorted(dict_tfidf_val.items(),key=operator.itemgetter(1),reverse=True)) 
    print(sorted_d)
    count_num=0
    tfidf_file=[]

    for item in sorted_d.keys():

        if (count_num != 5):
            tfidf_file.append(item)
        else: 
            break
        count_num=count_num+1
    
    return tfidf_file

def process_query():

    #query_input=input("Enter the Input text for Query ")
    query_input="lion stood thoughtfully for a moment"
    query_preprocessed=DELSPCCHARS(query_input)
    tokens = word_tokenize(query_preprocessed )
    qf = [word.lower() for word in tokens if word not in stop_words and len(word) > 1] #Removing stopwords 
    print(qf)
    binary=calculate_top(binary_tfidf,qf)
    raw_count=calculate_top(raw_count_tfidf,qf)
    termfreq=calculate_top(Term_Frequency_tfidf,qf)
    log=calculate_top(log_tfidf,qf)
    doublelog=calculate_top(double_log_tfidf,qf)
    return binary,raw_count,termfreq,log,doublelog

binary,raw_count,termfreq,log,doublelog=process_query()

print("top 5 documents for binary tfidf are:")
for i in binary:
    print(file_info[i])

print("top 5 documents for raw_count tfidf are:")
for i in raw_count:
    print(file_info[i])

print("top 5 documents for termfreq tfidf are:")
for i in termfreq:
    print(file_info[i])

print("top 5 documents for log tfidf are:")
for i in log:
    print(file_info[i])

print("top 5 documents for doublelog tfidf are:")
for i in doublelog:
    print(file_info[i])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 1 bbq
# 2 grommet
# 3 mothers
# 4 harmful
# 5 mowers
# 6 hell
# 7 herb!
# 8 hate
# 9 icm
# 10 murph
# 11 howlong
# 12 hi
# 13 roach
# 14 conan
# 15 coyote
# 16 imprrisk
# 17 horoscop
# 18 incarhel
# 19 murphy
# 20 bible
# 21 dirtword
# 22 insanity
# 23 impurmat
# 24 interv
# 25 insure
# 26 investi
# 27 cartoon_
# 28 bless
# 29 ivan
# 30 japrap
# 31 terms
# 32 jac&tuu
# 33 test
# 34 dym
# 35 killer
# 36 blooprs1
# 37 testchri
# 38 kid_diet
# 39 lawsuniv
# 40 kilsmur
# 41 test2
# 42 killself
# 43 lbinter
# 44 motrbike
# 45 murphys
# 46 ludeinfo
# 47 legal
# 48 simp
# 49 llong
# 50 office
# 51 lifeinfo
# 52 livnware
# 53 looser
# 54 lll
# 55 lif&love
# 56 lifeimag
# 57 lobquad
# 58 losers84
# 59 losers86
# 60 lozerzon
# 61 catstory
# 62 lozeuser
# 63 phunatdi
# 64 luggage
# 65 ludeinfo
# 66 m0dzmen
# 67 luzerzo2
# 68 manspace
# 69 manilla
# 70 madscrib
# 71 makebeer
# 72 maecenas
# 73 mailfrag
# 74 meinkamp
# 75 mtm
# 76 melodram
# 77 pun
# 78 mash
# 79 marines
# 80 memo
# 81 miranda
# 82 miamadvi
# 83 reasons
# 84 miami
# 85 f_tang
# 86 calvin
# 87 missheav
# 88 mutate
# 89 montpyth
# 90 mydaywss
# 91 misery
# 92 mrscienc
# 93 cars
# 94 news
# 95 myheart
# 96 newmex
# 97 newconst
# 98 naivewiz
# 99 boston
# 100 nysucks
# 101 cartwb
# 102 novel
# 103 nurds
# 104 nuke
# 105 cartoon
# 106 nukeplay
# 107 ohandre
# 108 chunnel
# 109 odearakk
# 110 o-ttalk
# 111 oilgluts
# 112 onetoone
# 113 oldeng
# 114 ozarks
# 115 onetotwo
# 116 p-law
# 117 deep
# 118 ookpik
# 119 opinion
# 120 phony
# 121 pizzawho
# 122 parabl
# 123 phorse
# 124 passage
# 125 peatchp
# 126 planeget
# 127 policpig
# 128 devils
# 129 prayer
# 130 poll2res
# 131 popconc
# 132 prawblim
# 133 dieter
# 134 popmusi
# 135 dead-r
# 136 pro-fact
# 137 psilaine
# 138 quest
# 139 reagan
# 140 radiolaf
# 141 raven
# 142 fuckyou2
# 143 ratings
# 144 donut
# 145 ratspit
# 146 rapmastr
# 147 drinkrul
# 148 research
# 149 docspeak
# 150 repair
# 151 reddye
# 152 rentals
# 153 report
# 154 ripoffpc
# 155 rocking
# 156 rockmus
# 157 dubltalk
# 158 drunk
# 159 t_zone
# 160 insult
# 161 corporat
# 162 cucumber
# 163 takenote
# 164 smackjok
# 165 skippy
# 166 smurfkil
# 167 iqtest
# 168 jokes
# 169 shuttleb
# 170 socecon
# 171 terbear
# 172 teens
# 173 spider
# 174 solviets
# 175 spydust
# 176 soleleer
# 177 social
# 178 stone
# 179 standard
# 180 sungenu
# 181 top10
# 182 termpoem
# 183 t-10
# 184 t-shirt
# 185 talebeat
# 186 texican
# 187 terrmcd'
# 188 languag
# 189 televisi
# 190 taping
# 191 y
# 192 tickmoon
# 193 textgrap
# 194 tfepisod
# 195 test
# 196 terrnieg
# 197 thecube
# 198 timetr
# 199 tfpoems
# 200 koans
# 201 hecomes
# 202 lawyer
# 203 toxcwast
# 204 let
# 205 the_math
# 206 thesis
# 207 voltron
# 208 trekwes
# 209 truths
# 210 cartoon
# 211 truthlsd
# 212 turbo
# 213 tribble
# 214 thermite
# 215 twinkie
# 216 why-me
# 217 wedding
# 218 wagon
# 219 whoon1st
# 220 wetdream
# 221 whoops
# 222 word
# 223 xtermin8
# 224 yjohncse
# 225 worldend
# 226 yuppies
# 227 who
# 228 billcat
# 229 zodiac
# 230 trukdeth
# 231 liceprof
# 232 limerick
# 233 jeffie
# 234 hotnnot
# 235 urban
# 236 tshirts
# 237 lines
# 238 units
# 239 vaguemag
# 240 st_silic
# 241 waitress
# 242 wagit
# 243 washroom
# 244 univ
# 245 strine
# 246 marriage
# 247 weight
# 248 welfare
# 249 lotsa
# 250 lion
# 251 math
# 252 math
# 253 yogisays
# 254 misc
# 255 wimptest
# 256 math
# 257 woodbugs
# 258 lozers
# 259 zgtoilet
# 260 xibovac
# 261 woolly_m
# 262 chainltr
# 263 climbing
# 264 church
# 265 commutin
# 266 co-car
# 267 netnews
# 268 childhoo
# 269 nigel
# 270 nigel
# 271 electric
# 272 eandb
# 273 court
# 274 elephant
# 275 nigel
# 276 hack
# 277 element
# 278 fartting
# 279 fascist
# 280 drinker
# 281 exam
# 282 excuses
# 283 fartinfo
# 284 idr2
# 285 nigel
# 286 nigel
# 287 final-ex
# 288 jokes
# 289 ourfathr
# 290 nigel
# 291 lawhunt
# 292 fuck!
# 293 fusion
# 294 nigel
# 295 lawskool
# 296 gas
# 297 rec
# 298 gd_guide
# 299 grammar
# 300 good
# 301 grospoem
# 302 passenge
# 303 german
# 304 nintendo
# 305 poli_t
# 306 polemom
# 307 potty
# 308 pepsideg
# 309 polly
# 310 pickup
# 311 polly_
# 312 moonshin
# 313 pournell
# 314 dover
# 315 proof
# 316 problem
# 317 psalm_re
# 318 proposal
# 319 pure
# 320 psalm23
# 321 pukeprom
# 322 psych_pr
# 323 prover_w
# 324 prooftec
# 325 college
# 326 leech
# 327 puzzles
# 328 curse
# 329 peanuts
# 330 python_s
# 331 quux_p
# 332 tuflife
# 333 flowchrt
# 334 pickup
# 335 pecker
# 336 smartass
# 337 height
# 338 eskimo
# 339 prac1
# 340 pipespec
# 341 hitlerap
# 342 hitler
# 343 hilbilly
# 344 how_to_i
# 345 steroid
# 346 hoosier
# 347 horoscop
# 348 htswfren
# 349 snipe
# 350 smokers
# 351 prac3
# 352 stereo
# 353 insuranc
# 354 idaho
# 355 televisi
# 356 inlaws1
# 357 humatran
# 358 sysadmin
# 359 law
# 360 humatra
# 361 realest
# 362 jargon
# 363 woodbine
# 364 kloo
# 365 italoink
# 366 jokeju07
# 367 jc-elvis
# 368 psycho
# 369 letter
# 370 rednecks
# 371 lampoon
# 372 sysman
# 373 letter_f
# 374 laws
# 375 letgosh
# 376 odd_to
# 377 lions
# 378 luvstory
# 379 prac4
# 380 farsi
# 381 nukwaste
# 382 lucky
# 383 one
# 384 socks
# 385 signatur
# 386 smurfs
# 387 smiley
# 388 primes
# 389 oracle
# 390 oxymoron
# 391 some_hu
# 392 spelin_r
# 393 studentb
# 394 strsdiet
# 395 princess
# 396 startrek
# 397 puzzle
# 398 mr
# 399 jrrt
# 400 telecom
# 401 humpty
# 402 shrink
# 403 prover
# 404 number
# 405 un
# 406 psalm
# 407 poli
# 408 quick
# 409 quantum
# 410 nosuch_nasfic
# 411 rent-a_cat
# 412 psalm_nixon
# 413 popmach
# 414 resrch_phrase
# 415 rinaldos
# 416 progrs
# 417 quotes
# 418 quotes
# 419 racist
# 420 shorties
# 421 texican
# 422 welfare
# 423 temphell
# 424 tnd
# 425 quotes
# 426 top10
# 427 squids
# 428 wisdom
# 429 bw-summe
# 430 aussie
# 431 bw-phwan
# 432 justify
# 433 outawork
# 434 speling
# 435 firstaid
# 436 la_times
# 437 supermar
# 438 oasis
# 439 oldtime
# 440 ambrose
# 441 oxymoron
# 442 gaiahuma
# 443 kid2
# 444 anim_lif
# 445 bad
# 446 wood
# 447 talkbizr
# 448 woodsmok
# 449 bagelope
# 450 variety1
# 451 variety3
# 452 empeval
# 453 variety2
# 454 epitaph
# 455 engrhyme
# 456 various
# 457 english
# 458 excuse30
# 459 excuse
# 460 vegkill
# 461 quack26
# 462 vonthomp
# 463 q
# 464 godmonth
# 465 gown
# 466 growth
# 467 cogdis
# 468 b12
# 469 mrsfield
# 470 hamburge
# 471 tuna
# 472 brewing
# 473 beginn
# 474 chili
# 475 mead
# 476 newcoke
# 477 cooking
# 478 candybar
# 479 coke1
# 480 coladrik
# 481 coke
# 482 vegan
# 483 jerky
# 484 snapple
# 485 meat2
# 486 coladrik
# 487 bakebred
# 488 oculis
# 489 drinks
# 490 pepper
# 491 fiber
# 492 x-drinks
# 493 turkey
# 494 fajitas
# 495 choco-ch
# 496 oatbran
# 497 recepies
# 498 kashrut
# 499 bread
# 500 coke_fan
# 501 candy
# 502 curry
# 503 appetiz
# 504 coke
# 505 fudge
# 506 aclamt
# 507 hotel
# 508 boneles2
# 509 dthought
# 510 tpquote2
# 511 tpquotes
# 512 gingbeer
# 513 gameshow
# 514 cooking
# 515 rinaldo
# 516 women
# 517 wrdnws1
# 518 wrdnws2
# 519 wrdnws3
# 520 wrdnws4
# 521 wrdnws5
# 522 wrdnws6
# 523 wrdnws7
# 524 wrdnws8
# 525 wrdnws9
# 526 letterbx
# 527 hierarch
# 528 ads
# 529 adt_miam
# 530 epikarat
# 531 earp
# 532 namm
# 533 kanalx
# 534 gd_flybd
# 535 widows
# 536 twinpeak
# 537 lazarus
# 538 hoonsrc
# 539 barney
# 540 barney
# 541 bb
# 542 bimg
# 543 bmdn01
# 544 libraway
# 545 wisconsi
# 546 twinkies
# 547 sanshop
# 548 scam
# 549 seeds42
# 550 top10st1
# 551 top10st2
# 552 transp
# 553 mundane
# 554 japantv
# 555 johann
# 556 just2
# 557 bnb_quot
# 558 bored
# 559 sw_err
# 560 skippy
# 561 recip1
# 562 shooters
# 563 slogans
# 564 smurf-03
# 565 smurf_co
# 566 soccer
# 567 beerjesus
# 568 bozo_tv
# 569 coffee
# 570 diet
# 571 jason
# 572 econridl
# 573 oliver
# 574 oliver02
# 575 sf-zine
# 576 subrdead
# 577 topten
# 578 how2bgod
# 579 hangover
# 580 netmask
# 581 chickens
# 582 classicm
# 583 cmu
# 584 commword
# 585 cookbkly
# 586 fearcola
# 587 hedgehog
# 588 horflick
# 589 alcohol
# 590 bbh_intv
# 591 beer-g
# 592 beergame
# 593 dining
# 594 iced
# 595 thievco
# 596 aeonint
# 597 mindvox
# 598 deathhem
# 599 bread
# 600 brownie
# 601 lion
# 602 lp-assoc
# 603 desk
# 604 disclym
# 605 flowchrt
# 606 flux_fix
# 607 packard
# 608 parsnip
# 609 penisprt
# 610 msfields
# 611 mtv
# 612 modstup
# 613 moslem
# 614 mov_rail
# 615 miamimth
# 616 missdish
# 617 consp
# 618 food
# 619 foodtips
# 620 cake
# 621 docdict
# 622 drinks
# 623 drive
# 624 bhang
# 625 booze1
# 626 booze2
# 627 cgs_lst
# 628 golnar
# 629 red-neck
# 630 reddwarf
# 631 renorthr
# 632 rns_bcl
# 633 rns_bwl
# 634 rns_ency
# 635 robot
# 636 subb_lis
# 637 staff
# 638 stuf10
# 639 stuf11
# 640 fusion
# 641 sfmovie
# 642 the_ant
# 643 mog-history
# 644 dalive
# 645 iremember
# 646 kilroy
# 647 cform2
# 648 msorrow
# 649 nameisreo
# 650 inquirer
# 651 ins1
# 652 buldrwho
# 653 bnbguide
# 654 epi_rns
# 655 epi_
# 656 epi_tton
# 657 gd_alf
# 658 epi_merm
# 659 epi_bnb
# 660 episimp2
# 661 gd_drwho
# 662 outlimit
# 663 lost
# 664 twilight
# 665 gd_gal
# 666 scratchy
# 667 gd_liqtv
# 668 gd_frasr
# 669 gd_maxhd
# 670 gd_ol
# 671 gd_hhead
# 672 epiquest
# 673 gd_sgrnd
# 674 gd_ql
# 675 ghostsch
# 676 gd_tznew
# 677 a-team
# 678 a_fish_c
# 679 a_tv_t-p
# 680 aboutada
# 681 adrian_e
# 682 allfam
# 683 allusion
# 684 amazing
# 685 anime
# 686 anime
# 687 hbo_spec
# 688 highland
# 689 hitchcok
# 690 wacky
# 691 wkrp
# 692 cast
# 693 christop
# 694 chung
# 695 clancy
# 696 comic_st
# 697 cultmov
# 698 maxheadr
# 699 facedeth
# 700 farsi
# 701 nukewar
# 702 number
# 703 spoonlis
# 704 sinksub
# 705 sorority
# 706 petshop
# 707 prac2
# 708 pracjoke
# 709 fed
# 710 cybrtrsh
# 711 hstlrtxt
# 712 homermmm
# 713 how2dotv
# 714 filmgoof
# 715 films_gl
# 716 fish
# 717 hitchcoc
# 718 is_story
# 719 fegg!int
# 720 feggaqui
# 721 feggmagi
# 722 normquot
# 723 history2
# 724 pol-corr
# 725 poopie
# 726 ppbeer
# 727 pot
# 728 headlnrs
# 729 hell
# 730 hum2
# 731 humor9
# 732 cokeform
# 733 contract
# 734 cookberk
# 735 cookie
# 736 cooplaws
# 737 cuisine
# 738 coffee
# 739 modemwld
# 740 minn
# 741 oam-001
# 742 oam
# 743 acronym
# 744 college
# 745 english
# 746 figure_1
# 747 crzycred
# 748 arnold
# 749 ateam
# 750 avengers
# 751 bbc_vide
# 752 beauty
# 753 blackadd
# 754 blake7
# 755 doc-says
# 756 dromes
# 757 eatme
# 758 free-cof
# 759 initials
# 760 old
# 761 post
# 762 quantum
# 763 resolutn
# 764 soporifi
# 765 swearfrn
# 766 tarot
# 767 c0dez
# 768 beer
# 769 butcher
# 770 curiousgeorgie
# 771 freudonseuss
# 772 normalboy
# 773 annoy
# 774 booze
# 775 diesmurf
# 776 elevator
# 777 get
# 778 how
# 779 normal
# 780 practica
# 781 dead2
# 782 dead3
# 783 dead4
# 784 dead5
# 785 radexposed
# 786 carowner
# 787 pat
# 788 bugs
# 789 hack7
# 790 happyhack
# 791 airlines
# 792 skincat
# 793 venganza
# 794 venison
# 795 homebrew
# 796 hop
# 797 hotpeper
# 798 necropls
# 799 three
# 800 dandwine
# 801 egglentl
# 802 eggroll1
# 803 egg-bred
# 804 engmuffn
# 805 focaccia
# 806 frogeye1
# 807 feista01
# 808 firecamp
# 809 garlpast
# 810 goldwatr
# 811 texbeef
# 812 greenchi
# 813 woods
# 814 wonton
# 815 gack!
# 816 unochili
# 817 whitbred
# 818 yogurt
# 819 insult
# 820 insults1
# 821 calamus
# 822 damiana
# 823 imbecile
# 824 oranchic
# 825 pbcookie
# 826 orgfrost
# 827 pasta001
# 828 penndtch
# 829 jon
# 830 hackmorality
# 831 whatbbs
# 832 hermsys
# 833 arcadian
# 834 appbred
# 835 antimead
# 836 apsaucke
# 837 awespinh
# 838 applepie
# 839 banana02
# 840 banana05
# 841 beershrm
# 842 batrbred
# 843 banana04
# 844 beershrp
# 845 banana03
# 846 baklava
# 847 banana01
# 848 berryeto
# 849 jawsalad
# 850 jambalay
# 851 jalapast
# 852 japice
# 853 jawgumbo
# 854 jungjuic
# 855 zuccmush
# 856 stagline
# 857 seafood
# 858 strattma
# 859 montoys
# 860 margos
# 861 mitch
# 862 zucantom
# 863 shuimai
# 864 blkbean
# 865 boarchil
# 866 blkbnsrc
# 867 btscke01
# 868 btscke03
# 869 bredcake
# 870 breadpud
# 871 bread
# 872 btscke02
# 873 brdpudd
# 874 burrito
# 875 buffwing
# 876 caesardr
# 877 btscke05
# 878 bunacald
# 879 butstcod
# 880 btscke04
# 881 capital
# 882 caramels
# 883 advrtize
# 884 bitnet
# 885 nzdrinks
# 886 recipe
# 887 recipe
# 888 recipe
# 889 recipe
# 890 recipe
# 891 recipe
# 892 recipe
# 893 richbred
# 894 recipe
# 895 recipe
# 896 recipe
# 897 oldtime
# 898 oakwood
# 899 recipe
# 900 recipe
# 901 renored
# 902 all_grai
# 903 amchap2
# 904 beer
# 905 beergame
# 906 beer-gui
# 907 gotukola
# 908 hitler
# 909 coollngo2
# 910 jimhood
# 911 acne1
# 912 aphrodis
# 913 bw
# 914 back1
# 915 blood
# 916 booknuti
# 917 acetab1
# 918 anorexia
# 919 atherosc
# 920 beesherb
# 921 1st_aid
# 922 cereal
# 923 chinese
# 924 arthriti
# 925 aniherb
# 926 curry
# 927 ayurved
# 928 brush1
# 929 critic
# 930 antibiot
# 931 proudlyserve
# 932 jayjay
# 933 bnbeg2
# 934 att
# 935 calculus
# 936 gumbo
# 937 btaco
# 938 beerwarn
# 939 byfb
# 940 qttofu
# 941 paddingurpapers
# 942 cartoon_laws
# 943 coffeebeerwomen
# 944 collected_quotes
# 945 childrenbooks
# 946 aggie
# 947 llamas
# 948 trekfume
# 949 confucius_say
# 950 enlightenment
# 951 labels
# 952 horoscope
# 953 fireplacein
# 954 ganamembers
# 955 girlspeak
# 956 religion
# 957 turing
# 958 valujet
# 959 computer
# 960 jokes1
# 961 lawyers
# 962 cops
# 963 fbipizza
# 964 mcd
# 965 nasaglenn
# 966 bhb
# 967 bond-2
# 968 indgrdn
# 969 insect1
# 970 quantity
# 971 sawyer
# 972 exidy
# 973 deadlysins
# 974 yuban
# 975 planetzero
# 976 aids
# 977 reeves
# 978 moore
# 979 chickenheadbbs
# 980 phxbbs-m
# 981 ukunderg
# 982 silverclaws
# 983 namaste
# 984 crazy
# 985 lifeonledge
# 986 lipkovits
# 987 basehead
# 988 draxamus
# 989 stressman
# 990 exylic
# 991 apsnet
# 992 lansing
# 993 heroic
# 994 onan
# 995 teevee
# 996 grail
# 997 mel
# 998 disclmr
# 999 hacktest
# 1000 hackingcracking
# 1001 analogy
# 1002 charity
# 1003 adameve
# 1004 bingbong
# 1005 ghostfun
# 1006 cheapfar
# 1007 modest
# 1008 mlverb
# 1009 poets
# 1010 saveface
# 1011 reconcil
# 1012 parades
# 1013 drugshum
# 1014 solders
# 1015 weights
# 1016 brainect
# 1017 throwawa
# 1018 shameonu
# 1019 symbol
# 1020 watchlip
# 1021 whatthe
# 1022 spacever
# 1023 kaboom
# 1024 hammock
# 1025 memory
# 1026 sigs
# 1027 zen
# 1028 adcopy
# 1029 nigel
# 1030 b-2
# 1031 manager
# 1032 abbott
# 1033 admin
# 1034 suicide2
# 1035 alcatax
# 1036 acronym
# 1037 alflog
# 1038 nigel10
# 1039 atombomb
# 1040 cancer
# 1041 answers
# 1042 badday
# 1043 bank
# 1044 boatmemo
# 1045 alabama
# 1046 beer
# 1047 catin
# 1048 beave
# 1049 beapimp
# 1050 bitchcar
# 1051 blackapp
# 1052 argotdic
# 1053 bigpic1
# 1054 blackhol
# 1055 cold
# 1056 cheapin
# 1057 blaster
# 1058 boe
# 1059 browneco
# 1060 btcisfre
# 1061 buzzword
# 1062 bugbreak
# 1063 cabbage
# 1064 butwrong
# 1065 chickens
# 1066 merry
# 1067 calif
# 1068 cockney
# 1069 nihgel_8
# 1070 catballs
# 1071 catranch
# 1072 macsfarm
# 1073 chinesec
# 1074 cbmatic
# 1075 change
# 1076 college
# 1077 making_y
# 1078 madhattr
# 1079 nukewar
# 1080 coldfake
# 1081 malechem
# 1082 number_k
# 1083 arab
# 1084 cucumber
# 1085 manners
# 1086 comrevi1
# 1087 anthropo
# 1088 addrmeri
# 1089 readme
# 1090 cowexplo
# 1091 rabbit
# 1092 dark
# 1093 d-ned
# 1094 failure
# 1095 cuchy
# 1096 art-fart
# 1097 dingding
# 1098 druggame
# 1099 deterior
# 1100 defectiv
# 1101 disaster
# 1102 roadpizz
# 1103 acronyms
# 1104 bad-d
# 1105 engineer
# 1106 doggun
# 1107 age
# 1108 murphy_l
# 1109 enquire
# 1110 beerdiag
# 1111 bad
# 1112 firstaid
# 1113 drinking
# 1114 record_
# 1115 middle
# 1116 flattax
# 1117 finalexm
# 1118 relative
# 1119 footfun
# 1120 moose
# 1121 forsooth
# 1122 revolt
# 1123 residncy
# 1124 from
# 1125 resrch_p
# 1126 freshman
# 1127 men&wome
# 1128 fwksfun
# 1129 mensroom
# 1130 goforth
# 1131 female
# 1132 gohome
# 1133 rinaldos
# {1: 'bbq.txt', 2: 'grommet.hum', 3: 'mothers.txt', 4: 'harmful.hum', 5: 'mowers.txt', 6: 'hell.jok', 7: 'herb!.hum', 8: 'hate.hum', 9: 'icm.hum', 10: 'murph.jok', 11: 'howlong.hum', 12: 'hi.tec', 13: 'roach.asc', 14: 'conan.txt', 15: 'coyote.txt', 16: 'imprrisk.hum', 17: 'horoscop.jok', 18: 'incarhel.hum', 19: 'murphy.txt', 20: 'bible.txt', 21: 'dirtword.txt', 22: 'insanity.hum', 23: 'impurmat.hum', 24: 'interv.hum', 25: 'insure.hum', 26: 'investi.hum', 27: 'cartoon_.txt', 28: 'bless.bc', 29: 'ivan.hum', 30: 'japrap.hum', 31: 'terms.hum', 32: 'jac&tuu.hum', 33: 'test.jok', 34: 'dym', 35: 'killer.hum', 36: 'blooprs1.asc', 37: 'testchri.txt', 38: 'kid_diet.txt', 39: 'lawsuniv.hum', 40: 'kilsmur.hum', 41: 'test2.jok', 42: 'killself.hum', 43: 'lbinter.hum', 44: 'motrbike.jok', 45: 'murphys.txt', 46: 'ludeinfo.txt', 47: 'legal.hum', 48: 'simp.txt', 49: 'llong.hum', 50: 'office.txt', 51: 'lifeinfo.hum', 52: 'livnware.hum', 53: 'looser.hum', 54: 'lll.hum', 55: 'lif&love.hum', 56: 'lifeimag.hum', 57: 'lobquad.hum', 58: 'losers84.hum', 59: 'losers86.hum', 60: 'lozerzon.hum', 61: 'catstory.txt', 62: 'lozeuser.hum', 63: 'phunatdi.ana', 64: 'luggage.hum', 65: 'ludeinfo.hum', 66: 'm0dzmen.hum', 67: 'luzerzo2.hum', 68: 'manspace.hum', 69: 'manilla.hum', 70: 'madscrib.hum', 71: 'makebeer.hum', 72: 'maecenas.hum', 73: 'mailfrag.hum', 74: 'meinkamp.hum', 75: 'mtm.hum', 76: 'melodram.hum', 77: 'pun.txt', 78: 'mash.hum', 79: 'marines.hum', 80: 'memo.hum', 81: 'miranda.hum', 82: 'miamadvi.hum', 83: 'reasons.txt', 84: 'miami.hum', 85: 'f_tang.txt', 86: 'calvin.txt', 87: 'missheav.hum', 88: 'mutate.hum', 89: 'montpyth.hum', 90: 'mydaywss.hum', 91: 'misery.hum', 92: 'mrscienc.hum', 93: 'cars.txt', 94: 'news.hum', 95: 'myheart.hum', 96: 'newmex.hum', 97: 'newconst.hum', 98: 'naivewiz.hum', 99: 'boston.geog', 100: 'nysucks.hum', 101: 'cartwb.son', 102: 'novel.hum', 103: 'nurds.hum', 104: 'nuke.hum', 105: 'cartoon.law', 106: 'nukeplay.hum', 107: 'ohandre.hum', 108: 'chunnel.txt', 109: 'odearakk.hum', 110: 'o-ttalk.hum', 111: 'oilgluts.hum', 112: 'onetoone.hum', 113: 'oldeng.hum', 114: 'ozarks.hum', 115: 'onetotwo.hum', 116: 'p-law.hum', 117: 'deep.txt', 118: 'ookpik.hum', 119: 'opinion.hum', 120: 'phony.hum', 121: 'pizzawho.hum', 122: 'parabl.hum', 123: 'phorse.hum', 124: 'passage.hum', 125: 'peatchp.hum', 126: 'planeget.hum', 127: 'policpig.hum', 128: 'devils.jok', 129: 'prayer.hum', 130: 'poll2res.hum', 131: 'popconc.hum', 132: 'prawblim.hum', 133: 'dieter.txt', 134: 'popmusi.hum', 135: 'dead-r', 136: 'pro-fact.hum', 137: 'psilaine.hum', 138: 'quest.hum', 139: 'reagan.hum', 140: 'radiolaf.hum', 141: 'raven.hum', 142: 'fuckyou2.txt', 143: 'ratings.hum', 144: 'donut.txt', 145: 'ratspit.hum', 146: 'rapmastr.hum', 147: 'drinkrul.jok', 148: 'research.hum', 149: 'docspeak.txt', 150: 'repair.hum', 151: 'reddye.hum', 152: 'rentals.hum', 153: 'report.hum', 154: 'ripoffpc.hum', 155: 'rocking.hum', 156: 'rockmus.hum', 157: 'dubltalk.jok', 158: 'drunk.txt', 159: 't_zone.jok', 160: 'insult', 161: 'corporat.txt', 162: 'cucumber.txt', 163: 'takenote.jok', 164: 'smackjok.hum', 165: 'skippy.hum', 166: 'smurfkil.hum', 167: 'iqtest', 168: 'jokes', 169: 'shuttleb.hum', 170: 'socecon.hum', 171: 'terbear.txt', 172: 'teens.txt', 173: 'spider.hum', 174: 'solviets.hum', 175: 'spydust.hum', 176: 'soleleer.hum', 177: 'social.hum', 178: 'stone.hum', 179: 'standard.hum', 180: 'sungenu.hum', 181: 'top10.txt', 182: 'termpoem.txt', 183: 't-10.hum', 184: 't-shirt.hum', 185: 'talebeat.hum', 186: 'texican.dic', 187: "terrmcd'.hum", 188: 'languag.jok', 189: 'televisi.hum', 190: 'taping.hum', 191: 'y.txt', 192: 'tickmoon.hum', 193: 'textgrap.hum', 194: 'tfepisod.hum', 195: 'test.hum', 196: 'terrnieg.hum', 197: 'thecube.hum', 198: 'timetr.hum', 199: 'tfpoems.hum', 200: 'koans.txt', 201: 'hecomes.jok', 202: 'lawyer.jok', 203: 'toxcwast.hum', 204: 'let.go', 205: 'the_math.hel', 206: 'thesis.beh', 207: 'voltron.hum', 208: 'trekwes.hum', 209: 'truths.hum', 210: 'cartoon.laws', 211: 'truthlsd ...
